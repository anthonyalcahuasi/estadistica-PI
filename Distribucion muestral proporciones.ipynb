# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt #Biblioteca para la salida gráfica.
# %matplotlib inline
import math
from math import sqrt

# %%
P=0.75
p=0.65
n=100

# %%
EM=(sqrt((P*(1-P))/n))
print(EM)
# Out:
# 0.04330127018922193

# %%
Z=(p-P)/EM
print(Z)
# Out:
# -2.3094010767585025

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#P(p<0.65)=0.5-0.4896
resultado=0.5-0.4896
print(resultado)
# Out:
# 0.01040000000000002
